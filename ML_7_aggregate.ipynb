# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pm_df = spark.read.parquet('dbfs:/mnt/ml-etl-output-data/MOP/mop_sample_dataset/mop_7_day/part-00000-tid-35254586342822082-45edad9f-6ff3-4fad-893d-b92fcb7c140f-114420-1-c000.snappy.parquet')
display(pm_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
mop_df = pm_df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
numeric_columns = list(mop_df._get_numeric_data().columns)
categorical_columns = list(set(mop_df.columns)-set(numeric_columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mop_df[categorical_columns] = mop_df[categorical_columns].fillna(value='unk')
mop_df[numeric_columns] = mop_df[numeric_columns].fillna(value=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = mop_df.drop(['mac', 'cmts_md_if_name', 'account', 'cmts', 
                 'postal_zip_code', 'event_date', 'shub',
                 'us_port', 'smt', 'phub', 'is_port_lvl_flg', 'channel_number', 'model'], axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
numeric_columns = list(df._get_numeric_data().columns)
categorical_columns = list(set(df.columns)-set(numeric_columns))
print(categorical_columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[]
# </div>

# %%
# for i in ['is_port_lvl_flg', 'model', 'channel_number', 'phub']:
#     #subject to change
#     cond = df[i].value_counts(normalize=True) <= 0.05
#     others = cond[cond].index
#     others_dict = {k: "others" for k in others}
#     df[i] = df[i].replace(others_dict)
#     df[i].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# encoded_df = pd.get_dummies(df, columns=['is_port_lvl_flg', 'model', 'channel_number', 'phub'], 
#                             prefix=['is_port_lvl_flg', 'model', 'channel_number', 'phub'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_df = df.drop(['downtime_full_day_avg'], axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: (1477000, 115)</div>

# %%
features = training_df.drop(['target_output_value'], axis = 1)
targets = np.array(training_df['target_output_value'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.33, random_state=1,shuffle=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.33, random_state=1,shuffle=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(663025, 114)
# (663025,)
# (326565, 114)
# (326565,)
# (487410, 114)
# (487410,)
# </div>

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
base_learners = [
                 ('xgb', XGBClassifier(n_estimators = 200)),
                 ('rf', RandomForestClassifier(n_estimators = 300, max_depth = 10, min_samples_split = 4, min_samples_leaf = 2))             
                ]

model = StackingClassifier(estimators=base_learners, cv = 3, n_jobs = -1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
model.fit(X_train, y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: StackingClassifier(cv=3,
#                    estimators=[(&#39;xgb&#39;,
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
# ...

# %%
# model = XGBClassifier(booster = "gbtree",colsample_bytree = 0.8, eta = 0.3, gamma = 0, max_depth = 6, n_estimators = 10,objective = "reg:logistic",reg_alpha = 0,reg_lambda = 0.625, subsample = 0.8,tree_method="auto")
# model = GradientBoostingClassifier()
# model.fit(X_train, y_train)
# decision_tree = DecisionTreeClassifier(max_depth = 5, min_samples_split = 4, min_samples_leaf = 4)
# decision_tree.fit(X_train, y_train)
# rf = RandomForestClassifier(n_estimators = 300, max_depth = 10, min_samples_split = 4, min_samples_leaf = 2, n_jobs = -1)
# rf.fit(X_train, y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
y_predict_train = model.predict(X_train)
print("confusion matrix:") 
print(confusion_matrix(y_train, y_predict_train))
print("prediction accuracy:") 
print(accuracy_score(y_train, y_predict_train))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">confusion matrix:
# [[425340  19853]
#  [ 78590 139242]]
# prediction accuracy:
# 0.8515244523208024
# </div>

# %%
sorted_idx = model.feature_importances_.argsort()[::-1]
imp_features = list(features.columns[sorted_idx])
imp_features_values = list(model.feature_importances_[sorted_idx])
top_features = list(zip(imp_features, imp_features_values))
# plt.barh(features[sorted_idx], model.feature_importances_[sorted_idx])
# plt.xlabel("Xgboost Feature Importance"
#print(top_features)
imp_feature_list = zip(imp_features, imp_features_values)
print(list(imp_feature_list))
# print(imp_features)
# print(imp_features_values)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# ...

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
#Changing threshold for value
y_predict = (model.predict_proba(X_val)[:,1]>=0.35).astype(int)
print("confusion matrix:") 
print(confusion_matrix(y_val, y_predict))
print("prediction accuracy:") 
print(accuracy_score(y_val, y_predict))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
y_predict_test = model.predict(X_test)
print("confusion matrix:") 
print(confusion_matrix(y_test, y_predict_test))
print("prediction accuracy:") 
print(accuracy_score(y_test, y_predict_test))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
rf_predict_val = rf.predict(X_val)
print("confusion matrix:") 
print(confusion_matrix(y_val, rf_predict_val))
print("prediction accuracy:") 
print(accuracy_score(y_val, rf_predict_val))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

sc_recall = recall_score(y_val, y_predict)
sc_prec = precision_score(y_val, y_predict)
print("recall: ", sc_recall)
print("precision: ", sc_prec)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from sklearn.metrics import f1_score
print(f1_score(y_test, y_predict_test))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
