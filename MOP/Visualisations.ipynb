# %%
xgb_feature_list = [[('us_util_used_cntn_req_mslots_var', 0.11420507), ('cmts_cm_us_signal_noise_sum_avg', 0.072200365), ('us_util_total_cntn_req_mslots_kurtosis', 0.0608861), ('us_util_ucastgranted_mslots_var', 0.060753625), ('cmts_cm_us_signal_noise_avg_avg', 0.05125187), ('cmts_cm_us_signal_noise_avg_var', 0.032815762), ('us_util_ucastgranted_mslots_avg', 0.031935733), ('cmts_cm_us_signal_noise_max_var', 0.03159221), ('cmts_cm_us_signal_noise_sum_var', 0.02994259), ('cmts_cm_us_signal_noise_sum_kurtosis', 0.02656845), ('cmts_cm_us_rx_power_avg_kurtosis', 0.02490864), ('cmts_cm_us_rx_power_sum_kurtosis', 0.023380658), ('cmts_cm_us_rx_power_max_avg', 0.021982672), ('cmts_cm_us_rx_power_max_kurtosis', 0.021458905), ('1200_hrs_kurtosis', 0.02036417), ('phub_PB01', 0.01744999), ('cmts_cm_us_rx_power_avg_avg', 0.016985252), ('cmts_cm_us_rx_power_sum_avg', 0.015906438), ('us_util_used_cntn_req_mslots_kurtosis', 0.014179278), ('cmts_cm_us_signal_noise_avg_kurtosis', 0.013286081), ('cmts_cm_us_unerroreds_kurtosis', 0.013230287), ('us_util_total_cntn_req_mslots_var', 0.0128531605), ('model_CODA4582U', 0.011506793), ('us_throughput_bps_95_var', 0.010846345), ('1200_hrs_var', 0.010269087), ('us_bytes_var', 0.01026793), ('codeword_error_rate_kurtosis', 0.009833728), ('rop_kurtosis', 0.009664171), ('codeword_error_rate_avg', 0.009500704), ('cmts_cm_us_signal_noise_max_kurtosis', 0.009479916), ('cmts_cm_us_signal_noise_max_avg', 0.008472462), ('us_util_total_mslots_avg', 0.007507108), ('us_util_used_cntn_mslots_avg', 0.007441639), ('rop_avg', 0.0064649098), ('us_util_used_cntn_req_mslots_avg', 0.006247807), ('phub_POWD1', 0.005903852), ('cmts_cm_us_unerroreds_var', 0.0058956547), ('us_util_total_mslots_kurtosis', 0.005630391), ('0100_hrs_avg', 0.005611724), ('cmts_cm_us_rx_power_sum_var', 0.005609775), ('us_throughput_bps_98_var', 0.0055005355), ('phub_PM01', 0.005366773), ('phub_PT06', 0.005165439), ('phub_PP03', 0.005162656), ('phub_PH01', 0.005037527), ('us_throughput_max_var', 0.0047002584), ('interface_count_kurtosis', 0.004670883), ('us_util_total_mslots_var', 0.0045724977), ('us_bytes_kurtosis', 0.004425197), ('phub_PT07', 0.0042663864), ('us_util_total_cntn_init_maint_mslots_avg', 0.0041599977), ('us_bytes_avg', 0.0039323024), ('us_throughput_max_avg', 0.003908254), ('capacity_bps_var', 0.0036924148), ('0600_hrs_kurtosis', 0.0032918402), ('us_util_coll_cntn_mslots_kurtosis', 0.003281687), ('us_throughput_bps_95_avg', 0.0032244108), ('us_util_coll_cntn_init_maint_mslots_kurtosis', 0.0031910758), ('us_util_used_cntn_mslots_var', 0.0031299638), ('us_util_coll_cntn_init_maint_mslots_avg', 0.0030304268), ('1200_hrs_avg', 0.0028441907), ('us_util_total_cntn_mslots_kurtosis', 0.0027799853), ('1800_hrs_kurtosis', 0.002323617), ('model_CGN3U', 0.002251218), ('cmts_cm_us_unerroreds_avg', 0.0022108483), ('capacity_bps_kurtosis', 0.0021810397), ('cmts_cm_us_rx_power_max_var', 0.0020112018), ('us_util_ucastgranted_mslots_kurtosis', 0.0018157903), ('us_throughput_bps_avg', 0.0016872135), ('us_util_total_cntn_init_maint_mslots_kurtosis', 0.0016610124), ('phub_PT08', 0.0016468845), ('phub_PDCB1', 0.0015953801), ('us_util_coll_cntn_mslots_var', 0.0015766069), ('us_util_coll_cntn_mslots_avg', 0.0011327539), ('cmts_cm_us_uncorrectables_kurtosis', 0.0010866176), ('us_throughput_bps_98_kurtosis', 0.0010651385), ('0600_hrs_var', 0.0009351718), ('us_util_used_cntn_mslots_kurtosis', 0.0009303751), ('us_util_total_cntn_mslots_avg', 0.0008416713), ('1800_hrs_avg', 0.0008258779), ('cmts_cm_us_correcteds_kurtosis', 0.000771905), ('us_throughput_bps_var', 0.00074949017), ('phub_POMK1', 0.00071780646), ('us_util_total_cntn_init_maint_mslots_var', 0.00067937473), ('phub_unk', 0.00062217255), ('phub_PONK1', 0.0006179951), ('capacity_bps_avg', 0.00061071786), ('cmts_cm_us_rx_power_avg_var', 0.00057513424), ('codeword_error_rate_var', 0.0005740796), ('model_CGM4140COM', 0.00055701425), ('2400_hrs_avg', 0.00051407644), ('cmts_cm_us_correcteds_var', 0.0005033135), ('rop_var', 0.00042520848), ('interface_count_avg', 0.00038870005), ('cmts_cm_us_uncorrectables_var', 0.00025710659), ('us_throughput_bps_98_avg', 3.1453535e-05), ('us_util_total_cntn_req_data_mslots_avg', 0.0), ('phub_PNWD', 0.0), ('phub_PNSJ', 0.0), ('phub_PO01', 0.0), ('us_util_coll_cntn_req_mslots_avg', 0.0), ('us_util_coll_cntn_req_mslots_var', 0.0), ('phub_PO02', 0.0), ('us_util_coll_cntn_req_mslots_kurtosis', 0.0), ('0100_hrs_kurtosis', 0.0), ('us_util_total_cntn_req_data_mslots_var', 0.0), ('us_util_total_cntn_req_data_mslots_kurtosis', 0.0), ('us_util_used_cntn_req_data_mslots_avg', 0.0), ('phub_PO03', 0.0), ('us_util_used_cntn_req_data_mslots_kurtosis', 0.0), ('us_util_coll_cntn_req_data_mslots_avg', 0.0), ('us_util_coll_cntn_req_data_mslots_var', 0.0), ('us_util_coll_cntn_req_data_mslots_kurtosis', 0.0), ('phub_PNPK', 0.0), ('phub_PNMH', 0.0), ('phub_PNMC', 0.0), ('us_util_used_cntn_req_data_mslots_var', 0.0), ('phub_POBA1', 0.0), ('us_util_total_cntn_req_mslots_avg', 0.0), ('phub_POAL1', 0.0), ('phub_PT05', 0.0), ('network_topology_key_avg', 0.0), ('network_topology_key_var', 0.0), ('network_topology_key_kurtosis', 0.0), ('interface_count_var', 0.0), ('phub_PT04', 0.0), ('phub_PT01', 0.0), ('phub_PP02', 0.0), ('phub_PP01', 0.0), ('phub_POWN1', 0.0), ('phub_POPF1', 0.0), ('phub_POOV1', 0.0), ('phub_POOR2', 0.0), ('us_util_total_cntn_mslots_var', 0.0), ('phub_POMC1', 0.0), ('phub_POKW1', 0.0), ('phub_POBL1', 0.0), ('phub_POBA2', 0.0), ('us_util_used_cntn_init_maint_mslots_var', 0.0), ('us_util_used_cntn_init_maint_mslots_avg', 0.0), ('phub_PNED', 0.0), ('us_util_used_cntn_init_maint_mslots_kurtosis', 0.0), ('model_CGN3ACSMR', 0.0), ('channel_number_3', 0.0), ('channel_number_2', 0.0), ('channel_number_1', 0.0), ('channel_number_0', 0.0), ('model_TG4482A', 0.0), ('model_TG3482P2', 0.0), ('model_TG3482G', 0.0), ('model_TG3482', 0.0), ('model_CGN3AMF', 0.0), ('model_CGN3-ROG', 0.0), ('phub_PNFR', 0.0), ('model_CGM4331COM', 0.0), ('is_port_lvl_flg_S', 0.0), ('cmts_cm_us_uncorrectables_avg', 0.0), ('is_port_lvl_flg_P', 0.0), ('is_port_lvl_flg_O', 0.0), ('2400_hrs_kurtosis', 0.0), ('2400_hrs_var', 0.0), ('1800_hrs_var', 0.0), ('0600_hrs_avg', 0.0), ('phub_PC01', 0.0), ('phub_PDND1', 0.0), ('phub_PDSJ1', 0.0), ('phub_PG02', 0.0), ('us_util_coll_cntn_init_maint_mslots_var', 0.0), ('0100_hrs_var', 0.0), ('phub_PNCT', 0.0), ('phub_PNCK', 0.0), ('phub_PNBH', 0.0), ('phub_PN02', 0.0), ('phub_PM02', 0.0), ('phub_PL04', 0.0), ('phub_PL02', 0.0), ('us_throughput_bps_kurtosis', 0.0), ('phub_PL01', 0.0), ('phub_PG10', 0.0), ('us_throughput_max_kurtosis', 0.0), ('phub_PG09', 0.0), ('phub_PG08', 0.0), ('us_throughput_bps_95_kurtosis', 0.0), ('phub_PG07', 0.0), ('phub_PG05', 0.0), ('phub_PG03', 0.0), ('cmts_cm_us_correcteds_avg', 0.0)]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rf_feature_list = [('us_util_ucastgranted_mslots_avg', 0.13495748324476592), ('cmts_cm_us_signal_noise_sum_kurtosis', 0.10301714084510656), ('cmts_cm_us_signal_noise_sum_var', 0.09537417991310915), ('cmts_cm_us_signal_noise_sum_avg', 0.09044814881882873), ('cmts_cm_us_rx_power_sum_kurtosis', 0.06289266681266233), ('cmts_cm_us_rx_power_sum_avg', 0.054909187867551126), ('cmts_cm_us_rx_power_max_avg', 0.045556562784367496), ('us_util_used_cntn_req_mslots_var', 0.040141345755630164), ('us_util_used_cntn_req_mslots_avg', 0.03491738817388508), ('cmts_cm_us_rx_power_max_kurtosis', 0.03474041157839381), ('cmts_cm_us_rx_power_sum_var', 0.0333054151048588), ('1200_hrs_avg', 0.030864828003259993), ('cmts_cm_us_rx_power_avg_var', 0.01937200326165645), ('cmts_cm_us_rx_power_avg_kurtosis', 0.018334879437711588), ('cmts_cm_us_rx_power_avg_avg', 0.014059701223386466), ('codeword_error_rate_avg', 0.011361210663201518), ('2400_hrs_kurtosis', 0.01099198308451101), ('cmts_cm_us_rx_power_max_var', 0.01019970745897908), ('cmts_cm_us_unerroreds_kurtosis', 0.009090758532842955), ('cmts_cm_us_unerroreds_avg', 0.0077304011489954085), ('cmts_cm_us_signal_noise_max_avg', 0.007575198142314216), ('1200_hrs_kurtosis', 0.0070832832912768335), ('cmts_cm_us_signal_noise_max_var', 0.006938466587179878), ('cmts_cm_us_uncorrectables_avg', 0.0062166229490804355), ('us_util_total_mslots_kurtosis', 0.006209114447668737), ('codeword_error_rate_kurtosis', 0.0061446061150160795), ('codeword_error_rate_var', 0.00601553012387109), ('cmts_cm_us_uncorrectables_var', 0.0059536246399562315), ('1800_hrs_avg', 0.005911835433688482), ('capacity_bps_avg', 0.0058091032627415), ('0600_hrs_kurtosis', 0.004770266702194575), ('1800_hrs_kurtosis', 0.0036135357226448847), ('model_CGM4140COM', 0.003508882497360105), ('us_util_coll_cntn_init_maint_mslots_var', 0.0033751770127881343), ('cmts_cm_us_signal_noise_avg_var', 0.003356462550770865), ('us_throughput_bps_98_kurtosis', 0.0033129752531467992), ('us_util_coll_cntn_mslots_var', 0.0032259029795191295), ('us_util_coll_cntn_mslots_kurtosis', 0.003078945904881715), ('us_util_total_cntn_init_maint_mslots_avg', 0.0027772109877000307), ('cmts_cm_us_correcteds_avg', 0.0027269282887914807), ('cmts_cm_us_signal_noise_max_kurtosis', 0.0026237044082510308), ('cmts_cm_us_signal_noise_avg_avg', 0.0022819964207635617), ('us_bytes_var', 0.0022378082568919972), ('us_util_used_cntn_mslots_var', 0.0022351703147653985), ('1800_hrs_var', 0.0021415285635830545), ('capacity_bps_var', 0.001808180607160232), ('us_util_coll_cntn_init_maint_mslots_avg', 0.0017875136270124458), ('us_util_used_cntn_mslots_kurtosis', 0.001771043490219083), ('us_bytes_avg', 0.0016836943694610996), ('cmts_cm_us_unerroreds_var', 0.001653956475946957), ('cmts_cm_us_signal_noise_avg_kurtosis', 0.0016404778613993594), ('us_util_coll_cntn_mslots_avg', 0.0015389629322988408), ('us_util_total_mslots_avg', 0.0012461785716691653), ('us_util_total_cntn_init_maint_mslots_kurtosis', 0.001222917717805123), ('model_CODA4582U', 0.0011241604826812649), ('us_bytes_kurtosis', 0.0011120629237819021), ('us_throughput_max_var', 0.0011034516289641382), ('us_throughput_bps_avg', 0.000981126617288377), ('us_util_coll_cntn_init_maint_mslots_kurtosis', 0.0009174669371538529), ('model_CGM4331COM', 0.0008876718421707074), ('us_throughput_bps_95_var', 0.0007927057843794205), ('0600_hrs_avg', 0.0007538039136928543), ('us_util_total_cntn_req_mslots_var', 0.0007200478022740531), ('us_util_total_cntn_mslots_kurtosis', 0.0006908079487216367), ('2400_hrs_avg', 0.0005123003971068872), ('phub_PB01', 0.0004986004154910585), ('us_throughput_bps_98_avg', 0.00044034082897488353), ('us_util_total_cntn_mslots_var', 0.00039510305784772905), ('0100_hrs_avg', 0.0002989739170979047), ('capacity_bps_kurtosis', 0.0002870488254161401), ('us_util_total_cntn_mslots_avg', 0.00027705055536650825), ('us_throughput_bps_95_avg', 0.00027001852241261535), ('model_TG3482G', 0.00025313371872672083), ('model_CGN3U', 0.0002499007296449183), ('us_throughput_max_avg', 0.00018897349732507345), ('cmts_cm_us_uncorrectables_kurtosis', 0.0001782940907146399), ('us_util_total_mslots_var', 0.0001645704359066062), ('us_throughput_bps_var', 0.00014806205938866545), ('us_util_ucastgranted_mslots_var', 0.0001465390259512629), ('us_throughput_max_kurtosis', 0.00013828225983646714), ('us_util_total_cntn_req_mslots_kurtosis', 0.00011729426852099883), ('interface_count_var', 0.00010606511970385706), ('us_throughput_bps_98_var', 9.871038056871601e-05), ('us_util_total_cntn_req_mslots_avg', 8.677234846996072e-05), ('us_throughput_bps_kurtosis', 6.793461700488522e-05), ('rop_var', 6.497167398249572e-05), ('us_util_used_cntn_mslots_avg', 6.07044947042456e-05), ('is_port_lvl_flg_P', 4.545348572658175e-05), ('rop_kurtosis', 2.349089270319929e-05), ('us_throughput_bps_95_kurtosis', 2.1662378050742408e-05), ('interface_count_kurtosis', 1.2516167888385543e-05), ('channel_number_0', 1.1930087404039912e-05), ('is_port_lvl_flg_S', 8.730121527807822e-06), ('channel_number_1', 1.0555219056001828e-06), ('phub_POPF1', 0.0), ('us_util_ucastgranted_mslots_kurtosis', 0.0), ('us_util_coll_cntn_req_mslots_kurtosis', 0.0), ('phub_PT04', 0.0), ('phub_PT01', 0.0), ('interface_count_avg', 0.0), ('network_topology_key_kurtosis', 0.0), ('network_topology_key_var', 0.0), ('network_topology_key_avg', 0.0), ('phub_PT06', 0.0), ('phub_PT07', 0.0), ('phub_PT05', 0.0), ('phub_POWD1', 0.0), ('us_util_total_cntn_req_data_mslots_avg', 0.0), ('us_util_coll_cntn_req_data_mslots_avg', 0.0), ('us_util_coll_cntn_req_mslots_var', 0.0), ('us_util_total_cntn_req_data_mslots_var', 0.0), ('us_util_coll_cntn_req_mslots_avg', 0.0), ('us_util_total_cntn_req_data_mslots_kurtosis', 0.0), ('us_util_used_cntn_req_data_mslots_avg', 0.0), ('us_util_used_cntn_req_data_mslots_var', 0.0), ('us_util_used_cntn_req_data_mslots_kurtosis', 0.0), ('us_util_used_cntn_req_mslots_kurtosis', 0.0), ('us_util_coll_cntn_req_data_mslots_var', 0.0), ('phub_PP03', 0.0), ('phub_PP01', 0.0), ('us_util_coll_cntn_req_data_mslots_kurtosis', 0.0), ('phub_POWN1', 0.0), ('us_util_total_cntn_init_maint_mslots_var', 0.0), ('phub_PP02', 0.0), ('us_util_used_cntn_init_maint_mslots_avg', 0.0), ('us_util_used_cntn_init_maint_mslots_var', 0.0), ('us_util_used_cntn_init_maint_mslots_kurtosis', 0.0), ('phub_PL02', 0.0), ('phub_PONK1', 0.0), ('phub_POOV1', 0.0), ('channel_number_2', 0.0), ('phub_PN02', 0.0), ('phub_PM02', 0.0), ('2400_hrs_var', 0.0), ('phub_PM01', 0.0), ('is_port_lvl_flg_O', 0.0), ('phub_PL04', 0.0), ('model_CGN3-ROG', 0.0), ('model_CGN3ACSMR', 0.0), ('model_CGN3AMF', 0.0), ('model_TG3482', 0.0), ('model_TG3482P2', 0.0), ('model_TG4482A', 0.0), ('channel_number_3', 0.0), ('rop_avg', 0.0), ('phub_PC01', 0.0), ('phub_PDCB1', 0.0), ('phub_PDND1', 0.0), ('phub_PDSJ1', 0.0), ('phub_PG02', 0.0), ('phub_PG03', 0.0), ('phub_PG05', 0.0), ('phub_PG07', 0.0), ('phub_PG08', 0.0), ('phub_PG09', 0.0), ('phub_PG10', 0.0), ('phub_PH01', 0.0), ('phub_PNBH', 0.0), ('1200_hrs_var', 0.0), ('phub_PNCK', 0.0), ('phub_PNCT', 0.0), ('phub_POOR2', 0.0), ('phub_PL01', 0.0), ('phub_POMK1', 0.0), ('phub_POMC1', 0.0), ('phub_POKW1', 0.0), ('phub_POBL1', 0.0), ('phub_POBA2', 0.0), ('phub_POBA1', 0.0), ('phub_POAL1', 0.0), ('phub_PO03', 0.0), ('phub_PO02', 0.0), ('phub_PO01', 0.0), ('phub_PNWD', 0.0), ('phub_PNSJ', 0.0), ('phub_PNPK', 0.0), ('phub_PNMH', 0.0), ('phub_PNMC', 0.0), ('phub_PT08', 0.0), ('cmts_cm_us_correcteds_var', 0.0), ('cmts_cm_us_correcteds_kurtosis', 0.0), ('phub_PNFR', 0.0), ('phub_PNED', 0.0), ('0100_hrs_var', 0.0), ('0100_hrs_kurtosis', 0.0), ('0600_hrs_var', 0.0), ('phub_unk', 0.0)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#feature list

feature_list=[('outage_count_kurtosis', 0.24437921833165463), ('outage_count_avg',
0.23264987346716084), ('outage_count_var', 0.18023761343677525),
('cmts_cm_us_signal_noise_sum_var', 0.037431887420804916),
('cmts_cm_us_signal_noise_sum_avg', 0.021236037457656905),
('cmts_cm_us_signal_noise_sum_kurtosis', 0.015797515673794997),
('cmts_cm_us_signal_noise_avg_var', 0.011154306658158768),
('cmts_cm_us_rx_power_sum_avg', 0.009827352093803391),
('us_util_ucastgranted_mslots_avg', 0.009717136520661843),
('us_util_used_cntn_req_mslots_avg', 0.009317531400013417),
('cmts_cm_us_rx_power_sum_kurtosis', 0.009142737901599569),
('us_util_ucastgranted_mslots_kurtosis', 0.008981957265934724),
('us_util_used_cntn_req_mslots_var', 0.008703228506084426),
('us_util_ucastgranted_mslots_var', 0.008695684352323473),
('us_util_used_cntn_req_mslots_kurtosis', 0.007905534212653801),
('cmts_cm_us_rx_power_sum_var', 0.0056176976722758475),
('cmts_cm_us_rx_power_avg_avg', 0.005296266655350356),
('cmts_cm_us_signal_noise_avg_avg', 0.004880984098874512),
('cmts_cm_us_signal_noise_max_var', 0.004819884025073513),
('cmts_cm_us_signal_noise_avg_kurtosis', 0.004577914213507246),
('cmts_cm_us_rx_power_max_kurtosis', 0.0041479560065431605),
('cmts_cm_us_rx_power_max_var', 0.003973216806064681),
('cmts_cm_us_rx_power_avg_var', 0.0038721624619248484),
('us_util_total_mslots_avg', 0.003847880125778472),
('cmts_cm_us_signal_noise_max_kurtosis', 0.00340638106762671),
('cmts_cm_us_signal_noise_max_avg', 0.0033875052496400806),
('us_util_total_cntn_init_maint_mslots_avg', 0.0033475734900272093),
('cmts_cm_us_rx_power_max_avg', 0.003323178533947681),
('cmts_cm_us_rx_power_avg_kurtosis', 0.0033059562838002425),
('us_util_used_cntn_mslots_var', 0.003117414311521904),
('us_util_used_cntn_mslots_avg', 0.002946191360402206),
('us_util_total_cntn_mslots_var', 0.002933709990315791),
('codeword_error_rate_avg', 0.002926390210919843),
('us_util_total_cntn_mslots_avg', 0.0028577600299987244),
('us_util_total_cntn_req_mslots_var', 0.0028570173248056783),
('us_util_used_cntn_mslots_kurtosis', 0.0028287101286043077),
('us_throughput_max_var', 0.0028266474487284353),
('us_util_total_mslots_var', 0.0028146817888210955),
('us_util_total_cntn_req_mslots_avg', 0.0026877581149225326),
('us_throughput_bps_98_var', 0.0026752023328131605), ('us_bytes_var',
0.0025603065177663598), ('us_throughput_bps_var', 0.002531851954242245),
('cmts_cm_us_unerroreds_var', 0.0025026109031351545),
('us_util_total_mslots_kurtosis', 0.0025001724798340828),
('us_util_coll_cntn_mslots_var', 0.0024909415426195313),
('us_util_coll_cntn_mslots_avg', 0.0024695092824981255),
('us_throughput_bps_95_var', 0.0024636268705604232),
('us_util_coll_cntn_init_maint_mslots_avg', 0.0024451312513282687),
('us_util_coll_cntn_init_maint_mslots_var', 0.0024291434271401856),
('us_util_total_cntn_init_maint_mslots_var', 0.0022843387620250554),
('us_bytes_kurtosis', 0.002248345294220362),
('us_throughput_bps_kurtosis', 0.0022021939711858447), ('us_bytes_avg',
0.0021790015569603943), ('us_throughput_bps_avg',
0.0021560422875750726), ('cmts_cm_us_unerroreds_avg',
0.0021464084465572277), ('us_util_coll_cntn_init_maint_mslots_kurtosis',
0.0021364682958275754), ('us_throughput_max_avg',
0.002123450837782847), ('us_throughput_bps_95_avg',
0.002107643895452162), ('us_throughput_bps_98_avg',
0.002104763063749436), ('us_throughput_max_kurtosis',
0.002073884665850578), ('us_util_total_cntn_mslots_kurtosis',
0.0020332538114184503), ('us_throughput_bps_95_kurtosis',
0.002029378736045601), ('us_util_total_cntn_req_mslots_kurtosis',
0.0019914454987541093), ('us_util_coll_cntn_mslots_kurtosis',
0.0019655884405426487), ('us_throughput_bps_98_kurtosis',
0.0019610569987559183), ('cmts_cm_us_uncorrectables_avg',
0.0019404557081424056), ('1200_hrs_avg', 0.001938135227402346),
('us_util_total_cntn_init_maint_mslots_kurtosis',
0.0019118307699806055), ('capacity_bps_kurtosis', 0.001849948204164125),
('cmts_cm_us_correcteds_avg', 0.0018246284097958843),
('capacity_bps_avg', 0.0018204754639702316),
('cmts_cm_us_unerroreds_kurtosis', 0.0018050662032396197),
('codeword_error_rate_var', 0.0017084446332936228), ('1200_hrs_var',
0.0016784375518523154), ('cmts_cm_us_uncorrectables_var',
0.001488396694946233), ('0600_hrs_avg', 0.001487979597341454),
('interface_count_var', 0.001486764738928717), ('capacity_bps_var',
0.0013612523480269877), ('0600_hrs_var', 0.0012028002775612378),
('1800_hrs_avg', 0.0011364058252227502), ('interface_count_avg',
0.0010808965515260172), ('cmts_cm_us_correcteds_var',
0.0010761101769867015), ('rop_kurtosis', 0.000993315061569826),
('2400_hrs_avg', 0.0009869242558572266), ('interface_count_kurtosis',
0.0009822883684956812), ('rop_var', 0.0009653371852015733),
('0100_hrs_avg', 0.0009094517204228506), ('rop_avg',
0.0008723717289501149), ('1800_hrs_var', 0.0008520372431823289),
('cmts_cm_us_uncorrectables_kurtosis', 0.0008463993594745345),
('codeword_error_rate_kurtosis', 0.0008348808422096061),
('1200_hrs_kurtosis', 0.0007769836294655834), ('0100_hrs_var',
0.0007080975781564284), ('0600_hrs_kurtosis', 0.0006683739420145745),
('2400_hrs_var', 0.0006415003771253269),
('cmts_cm_us_correcteds_kurtosis', 0.000491962355084044),
('1800_hrs_kurtosis', 0.0004577464971593297), ('2400_hrs_kurtosis',
0.0003144336263359029), ('0100_hrs_kurtosis', 0.0003085615885926603),
('us_util_used_cntn_init_maint_mslots_kurtosis', 5.215053222081768e-07),
('us_util_used_cntn_init_maint_mslots_var', 4.6392028992408264e-07),
('us_util_coll_cntn_req_mslots_kurtosis', 7.672274757546459e-08),
('us_util_used_cntn_init_maint_mslots_avg', 3.0886764517852606e-08),
('network_topology_key_kurtosis', 0.0),
('us_util_coll_cntn_req_data_mslots_var', 0.0),
('network_topology_key_var', 0.0), ('network_topology_key_avg', 0.0),
('us_util_coll_cntn_req_mslots_avg', 0.0),
('us_util_used_cntn_req_data_mslots_var', 0.0),
('us_util_coll_cntn_req_data_mslots_avg', 0.0),
('us_util_used_cntn_req_data_mslots_kurtosis', 0.0),
('us_util_used_cntn_req_data_mslots_avg', 0.0),
('us_util_total_cntn_req_data_mslots_kurtosis', 0.0),
('us_util_total_cntn_req_data_mslots_var', 0.0),
('us_util_total_cntn_req_data_mslots_avg', 0.0),
('us_util_coll_cntn_req_mslots_var', 0.0),
('us_util_coll_cntn_req_data_mslots_kurtosis', 0.0)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#sort the list to ascending by feature value

feature_list_ascending= sorted(feature_list, key=lambda x: x[1], reverse=False)
print(feature_list_ascending)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
#prepare the feature list name column - step 1 of 2
feature_columns_ascending = []
feature_imp_values_ascending= []

for value in feature_list_ascending:
  feature_columns_ascending.append(value[0])
  feature_imp_values_ascending.append(value[1])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#prepare the feature list name column - step 2 of 2
import re
feature_columns_cut = []

for str in feature_columns_ascending:
    pattern = r"_kurtosis|_sum|_var|_avg|_max"
    feature_columns_cut.append(re.sub(pattern,"",str))
print(feature_columns_cut)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
#combine the updated feature name column with its feature value
feature_dic_updated = dict(zip(feature_columns_cut,feature_imp_values_ascending))
print(feature_dic_updated)

#convert dict to list
feature_list_ascending_updated = list(feature_dic_updated.items())
print(feature_list_ascending_updated)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
#sort the updated list to desending
feature_list_desending = sorted(feature_list_ascending_updated, key=lambda x: x[1], reverse=True)
print(feature_list_desending)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
#for py chart
feature_columns_desending = []
feature_imp_values_desending = []

for value in feature_list_desending:
  feature_columns_desending.append(value[0])
  feature_imp_values_desending.append(value[1])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(8, 8), dpi=80)
plt.barh(feature_columns_desending[:10], feature_imp_values_desending[:10])
plt.ylabel("Important Feature Columns")
plt.xlabel("Importance Score")

# %%
# to be remove - pd don't give the data type
import pandas as pd

dict_feature_list_desending = {"Important Feature Columns":  feature_columns_desending, "Importance Score": feature_imp_values_desending}

df_final = pd.DataFrame(dict_feature_list_desending)
print(df_final)

#df.to_csv('/FileStore/tables/file1.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">               Important Feature Columns  Importance Score
# 0                           outage_count      2.443792e-01
# 1                cmts_cm_us_signal_noise      3.743189e-02
# 2                    cmts_cm_us_rx_power      9.827352e-03
# 3            us_util_ucastgranted_mslots      9.717137e-03
# 4           us_util_used_cntn_req_mslots      9.317531e-03
# 5                   us_util_total_mslots      3.847880e-03
# 6   us_util_total_cntn_init_maint_mslots      3.347573e-03
# 7               us_util_used_cntn_mslots      3.117414e-03
# 8              us_util_total_cntn_mslots      2.933710e-03
# ...

# %%
MOP_feature = spark.createDataFrame(feature_list_desending,schema=['Important_Feature_Columns', 'Importance_Score'])
MOP_feature.printSchema()
MOP_feature.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Important_Feature_Columns: string (nullable = true)
# -- Importance_Score: double (nullable = true)
#
# +-------------------------+--------------------+
# Important_Feature_Columns|    Importance_Score|
# +-------------------------+--------------------+
#              outage_count| 0.24437921833165463|
#      cmts_cm_us_signal...|0.037431887420804916|
#       cmts_cm_us_rx_power|0.009827352093803391|
#      us_util_ucastgran...|0.009717136520661843|
#      us_util_used_cntn...|0.009317531400013417|
#      us_util_total_mslots|0.003847880125778472|
#      us_util_total_cnt...|0.003347573490027...|
# ...

# %%
MOP_feature.createOrReplaceTempView('MOP_Important_Features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
drop table if exists default.MOP_Important_Features;

create table default.MOP_Important_Features as
(select * from `MOP_Important_Features`);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
drop table if exists default.MOP_Important_Features;

create table default.MOP_Important_Features as
(select * from `MOP_Important_Features`
order by Importance_Score Desc
limit 10);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from default.MOP_Important_Features;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
